# %%
# %matplotlib inline

# %%
import matplotlib as plt
import numpy as np
import PIL
import scipy.signal as sps
import matplotlib.image as mpimg

# %%
image0=mpimg.imread('D:\\PHD.Z\\Files\\PHD\\文献\\1.jpg')
image=image[:,:,1];

# %%
plt.pyplot.imshow(image)

# %%
# %%HTML
# <button onclick="$('.input, .prompt, .output_stderr, .output_error, .output_result').toggle();">Toggle Code</button>
# Out:
# <button onclick="$('.input, .prompt, .output_stderr, .output_error, .output_result').toggle();">Toggle Code</button>

# %%
psf=mpimg.imread('D:\\Supplementary Software\\psf.bmp')

# %%
plt.pyplot.imshow(psf)

# %%
image.astype('double');
psf.astype('double');

# %%
#psf_little=np.square(psf)[32:36,32:36];
psf_little=np.ones([50,50]);
plt.pyplot.imshow(psf_little)

# %%
im_blur=sps.convolve2d(image,psf_little,'same')
#im_blur.astype('uint8');
im_blur=im_blur/np.max(np.max(im_blur))
im_blur=255*im_blur
im_blur.astype('uint8')
# Out:
# array([[2, 2, 2, ..., 2, 2, 2],
#        [2, 2, 2, ..., 2, 2, 2],
#        [2, 2, 2, ..., 2, 2, 2],
#        ...,
#        [2, 2, 2, ..., 2, 2, 2],
#        [2, 2, 2, ..., 2, 2, 2],
#        [2, 2, 2, ..., 2, 2, 2]], dtype=uint8)

# %%
plt.pyplot.imshow(im_blur)

# %%
# ?plt.pyplot.imshow
